# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\anacondanew\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anacondanew\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anacondanew\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anacondanew\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anacondanew\lib\site-packages (from requests) (2025.6.15)

# %%
import requests
BASE_URL = "https://pokeapi.co/api/v2/"
def get_pokemon_info(name):
    url = (f"{BASE_URL}/pokemon/{name}")
    response = requests.get(url)
    
    if response.status_code == 200:
        pokemon_data = response.json()
        return pokemon_data
    else:
        print(f"Failed To Retrive data.\n Error: {response}")
pokemon_name = "pikachu"
pokemon_info = get_pokemon_info(pokemon_name)
if pokemon_info:
    print("Name:", pokemon_info['name'].capitalize())
    print("ID:", pokemon_info['id'])
    print("Height:", pokemon_info['height'])
    print("Weight:", pokemon_info['weight'])
# Out:
# Name: Pikachu
# ID: 25
# Height: 4
# Weight: 60
