# %%
import math
def prime_numbers(n):
    prime_num = []
    for i in range(2,n+1):
        is_prime = True
        for j in range(2,int(math.sqrt(i)) + 1):
            if i % j == 0:
                is_prime = False
                break
        if is_prime == True:
            prime_num.append(i)
    return prime_num

prime_numbers(20)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]

# %%
# !pip install collections
# Out:
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections

# %%
num = 2                 # prime numbers start from 2
limit = int(input("Enter the limit: "))

while num <= limit:
    is_prime = True
    i = 2

    # check if num is divisible by any number from 2 to num-1
    while i < num:
        if num % i == 0:
            is_prime = False
            break
        i += 1

    if is_prime:
        print(num, end=" ")

    num += 1
# Out:
# Enter the limit:  10
# 2 3 5 7

# %%
num = 2
limit = int(input("Enter The Limit:  "))
while num <= limit:
    is_prime = True
    i = 2
    while i < num:
        if num % i == 0:
            is_prime = False
            break
        i += 1
    if is_prime:
        print(num,end= " ")
    num +=1
# Out:
# Enter The Limit:   10
# 2 3 5 7

# %%
l1 = [1,2,34,3,432,22,1]
c = sorted(l1,reverse = True)
print(c)
# Out:
# [432, 34, 22, 3, 2, 1, 1]

# %%
l1.sort()
l1
# Out:
# [1, 1, 2, 3, 22, 34, 432]

# %%
l1.reverse()
l1
# Out:
# [432, 34, 22, 3, 2, 1, 1]

# %%
l1.copy()
# Out:
# [432, 34, 22, 3, 2, 1, 1]

# %%
d1 = {"A" : 2, "B" : 3}
d2 = {"A" : 4, "B" : 5}

# %%
d1.get("A")
# Out:
# 2

# %%
d1.keys()
# Out:
# dict_keys(['A', 'B'])

# %%
d1.values()
# Out:
# dict_values([2, 3])

# %%
d1.items()
# Out:
# dict_items([('A', 2), ('B', 3)])

# %%
d1.update(d2)

# %%
d1
# Out:
# {'A': 4, 'B': 5}
